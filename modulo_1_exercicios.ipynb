# %% [markdown]
# <a href="https://colab.research.google.com/github/karolinadornelas/curso-ebac-fullstack/blob/main/modulo_1_exercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo 01** | Python: Variáveis & Tipos de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução ao Google Colab;</li>
#   <li>Variáveis;</li>
#   <li>Números;</li>
#   <li><i>Strings;</i></li>
#   <li>Boleanos.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Google Colab

# %% [markdown]
# Crie uma célula de código que escreva o texto "Olá mundo!", utilize o comando `print`.

# %%
print('olá mundo!')
# Out:
# olá mundo!

# %% [markdown]
# Crie uma célua de texto e adicione uma imagem.

# %% [markdown]
# ---

# %% [markdown]
# ![doguinho.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2\. Números

# %% [markdown]
# Preencha as células de código para preencher os valores de (A), (B) e (C) na tabela de ticket médio abaixo:
#
# <br>
#
# | Dia   | Valor Total Vendas | Qtd Total Vendas | Ticket Medio |
# |-------|--------------------|------------------|--------------|
# | 19/01 | (A)                | 3                | 320.52       |
# | 20/01 | 834.47             | (B)              | 119.21       |
# | 23/01 | 15378.12           | 5                | (C)          |

# %%
# (A)
qtv_19 = 3
tktm_19 = 320.52

vtv_19 = qtv_19 * tktm_19
print(vtv)
# Out:
# 961.56

# %%
# (B)
vtv_20 = 834.47
tktm_20 = 119.21

qtv_20 = vtv_20/tktm_20
print(qtv_20)
# Out:
# 7.000000000000001

# %%
# (C)
vtv_23 = 15378.12
qtv_23 = 5

tktm_23 = vtv_23/qtv_23
print(tktm_23)
# Out:
# 3075.6240000000003

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Strings

# %% [markdown]
# Aplique três métodos distintos na *string* abaixo, você pode conferir alguns métodos neste [link](https://www.w3schools.com/python/python_ref_string.asp):

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'
print(cancao.replace('Roda mundo', 'Mundo roda'))
print(cancao.upper())
print(cancao.find('balão'))
# Out:
# Mundo roda, roda gigante, roda moinho, roda pião.
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.
# -1

# %% [markdown]
# Extraia da string abaixo o valor da taxa **selic** na variável `selic` e o valor do **ano** na variavel `ano`. Imprima os valores na tela.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'


taxa_selic = noticia[12:16]
selic = (taxa_selic.replace(',','.'))
print(selic)
print(type(selic))
selic = float(selic)
print(type(selic))

ano = noticia[-7]
print(ano)
print(type(ano))
ano=int(ano)
print(type(ano))
# Out:
# 2.75
# <class 'str'>
# <class 'float'>
# 6
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ## 4\. Booleanos

# %% [markdown]
# Utilize a tabela da verdade para responder: qual o valor da variável x?

# %%
a = False
b = True

x = not a & b
print(bool(x))
# Out:
# True
